# %% [markdown]
# # Déjame escuchar música

# %% [markdown]
# Los datos están almacenados en el archivo `/datasets/music_project_en.csv`.
#
# ¡Ahora sí, manos al código!

# %% [markdown]
# ## Etapa 1. Descripción de los datos <a id='data_review'></a>
#
# Abre los datos y examínalos.

# %%
# Importa pandas
import pandas as pd

# %%
# Lee el archivo y almacénalo en df
df = pd.read_csv('music_project_en.csv')

# %%
# Obtén las 10 primeras filas de la tabla df
df.head(10)
# Out:
#      userID                        Track            artist   genre  \
# 0  FFB692EC            Kamigata To Boots  The Mass Missile    rock
# 1  55204538  Delayed Because of Accident  Andreas Rönnberg    rock
# 2    20EC38            Funiculì funiculà       Mario Lanza     pop
# 3  A3DD03C9        Dragons in the Sunset        Fire + Ice    folk
# 4  E2DC1FAE                  Soul People        Space Echo   dance
# 5  842029A1                       Chains          Obladaet  rusrap
# 6  4CB90AA5                         True      Roman Messer   dance
# 7  F03E1C1F             Feeling This Way   Polina Griffith   dance
# 8  8FA1D3BE                     L’estate       Julia Dalia  ruspop
# 9  E772D5C0                    Pessimist               NaN   dance
#
#         City        time        Day
# 0  Shelbyville  20:28:33  Wednesday
# 1  Springfield  14:07:09     Friday
# 2  Shelbyville  20:58:07  Wednesday
# 3  Shelbyville  08:37:09     Monday
# 4  Springfield  08:34:34     Monday
# ...

# %%
# Obtén la información general sobre nuestros datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65079 entries, 0 to 65078
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0     userID  65079 non-null  object
#  1   Track     63736 non-null  object
#  2   artist    57512 non-null  object
#  3   genre     63881 non-null  object
#  4     City    65079 non-null  object
#  5   time      65079 non-null  object
#  6   Day       65079 non-null  object
# dtypes: object(7)
# memory usage: 3.5+ MB

# %% [markdown]
# Estas son nuestras observaciones sobre la tabla. Contiene siete columnas que almacenan los mismos tipos de datos: `object`.
#
# Según la documentación:
# - `' userID'`: identificador del usuario;
# - `'Track'`: título de la canción;
# - `'artist'`: nombre del artista;
# - `'genre'`: género de la canción;
# - `'City'`: ciudad del usuario;
# - `'time'`: la hora exacta en la que se reprodujo la canción;
# - `'Day'`: día de la semana.
#
# Podemos ver dos problemas con el estilo en los encabezados de la tabla:
# 1. Algunos encabezados están en mayúsculas, otros en minúsculas.
# 2. Time está como tipo object, cuando podría ser to-date-time.

# %% [markdown]
# Escribe aquí tus respuestas:
#
# 1. Tenemos solo datos categóricos como artistas, generos, ciudades y días según el método info().
#
# 2. Si considero que hay suficientes datos para hayar algún tipo de patrón, en cuanto a día de la semana, hora, ciudad, género, esto puede dar varios indicadores.
#
# 3. En track, artist y genre podemos ver datos nulos

# %%
# Conteo de valores faltantes
df.isna().sum()
# Out:
#   userID       0
# Track       1343
# artist      7567
# genre       1198
#   City         0
# time           0
# Day            0
# dtype: int64

# %%
# Muestra los nombres de las columnas
df.columns
# Out:
# Index(['  userID', 'Track', 'artist', 'genre', '  City  ', 'time', 'Day'], dtype='object')

# %%
# Bucle que itera sobre los encabezados y los pone todos en minúsculas
cleaned_columns = []

for col in df.columns:
  cleaned_columns.append(col.lower())
df.columns = cleaned_columns
df.columns
# Out:
# Index(['  userid', 'track', 'artist', 'genre', '  city  ', 'time', 'day'], dtype='object')

# %%
# Bucle que itera sobre los encabezados y elimina los espacios
cleaned_columns = []
for col in df.columns:
  cleaned_columns.append(col.strip())
df.columns = cleaned_columns
print(df.columns)
# Out:
# Index(['userid', 'track', 'artist', 'genre', 'city', 'time', 'day'], dtype='object')

# %%
# Cambia el nombre de la columna "userid" asignando una nueva lista
cleaned_columns[0] = 'user_id'
df.columns = cleaned_columns
df.columns
# Out:
# Index(['user_id', 'track', 'artist', 'genre', 'city', 'time', 'day'], dtype='object')

# %%
# Comprueba el resultado: lista de encabezados
df.columns
# Out:
# Index(['user_id', 'track', 'artist', 'genre', 'city', 'time', 'day'], dtype='object')

# %%
# Bucle en los encabezados reemplazando los valores ausentes con 'unknown'
columns_to_replace = ['track', 'artist', 'genre']
for col in columns_to_replace:
  df[col] = df[col].fillna('unknown')

# %%
# Cuenta los valores ausentes
print(df.isna().sum())
# Out:
# user_id    0
# track      0
# artist     0
# genre      0
# city       0
# time       0
# day        0
# dtype: int64

# %%
# Cuenta los duplicados explícitos
print(df.duplicated().sum())
# Out:
# 3826

# %%
# Elimina los duplicados explícitos
df = df.drop_duplicates()

# %%
# Comprueba de nuevo si hay duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Inspecciona los nombres de géneros únicos
df['genre'].unique()
# Out:
# array(['rock', 'pop', 'folk', 'dance', 'rusrap', 'ruspop', 'world',
#        'electronic', 'unknown', 'alternative', 'children', 'rnb', 'hip',
#        'jazz', 'postrock', 'latin', 'classical', 'metal', 'reggae',
#        'triphop', 'blues', 'instrumental', 'rusrock', 'dnb', 'türk',
#        'post', 'country', 'psychedelic', 'conjazz', 'indie',
#        'posthardcore', 'local', 'avantgarde', 'punk', 'videogame',
#        'techno', 'house', 'christmas', 'melodic', 'caucasian',
#        'reggaeton', 'soundtrack', 'singer', 'ska', 'salsa', 'ambient',
#        'film', 'western', 'rap', 'beats', "hard'n'heavy", 'progmetal',
#        'minimal', 'tropical', 'contemporary', 'new', 'soul', 'holiday',
#        'german', 'jpop', 'spiritual', 'urban', 'gospel', 'nujazz',
#        'folkmetal', 'trance', 'miscellaneous', 'anime', 'hardcore',
#        'progressive', 'korean', 'numetal', 'vocal', 'estrada', 'tango',
#        'loungeelectronic', 'classicmetal', 'dubstep', 'club', 'deep',
# ...

# %%
# Función para reemplazar los duplicados implícitos

def replace_wrong_values(df, column, wrong_values, correct_value):
    for wrong_value in wrong_values:
        df[column] = df[column].replace(wrong_value, correct_value)
    return df

# %%
# Elimina los duplicados implícitos
replace_wrong_values(df, 'genre', ['hip', 'hop', 'hip-hop'], 'hiphop')
# Out:
#         user_id                              track            artist  \
# 0      FFB692EC                  Kamigata To Boots  The Mass Missile
# 1      55204538        Delayed Because of Accident  Andreas Rönnberg
# 2        20EC38                  Funiculì funiculà       Mario Lanza
# 3      A3DD03C9              Dragons in the Sunset        Fire + Ice
# 4      E2DC1FAE                        Soul People        Space Echo
# ...         ...                                ...               ...
# 65074  729CBB09                            My Name            McLean
# 65075  D08D4A55  Maybe One Day (feat. Black Spade)       Blu & Exile
# 65076  C5E3A0D5                          Jalopiina           unknown
# 65077  321D0506                      Freight Train     Chas McDevitt
# 65078  3A64EF84          Tell Me Sweet Little Lies      Monica Lopez
#
#             genre         city      time        day
# 0            rock  Shelbyville  20:28:33  Wednesday
# ...

# %%
# Comprueba de nuevo los duplicados implícitos
df['genre'].unique()
# Out:
# array(['rock', 'pop', 'folk', 'dance', 'rusrap', 'ruspop', 'world',
#        'electronic', 'unknown', 'alternative', 'children', 'rnb',
#        'hiphop', 'jazz', 'postrock', 'latin', 'classical', 'metal',
#        'reggae', 'triphop', 'blues', 'instrumental', 'rusrock', 'dnb',
#        'türk', 'post', 'country', 'psychedelic', 'conjazz', 'indie',
#        'posthardcore', 'local', 'avantgarde', 'punk', 'videogame',
#        'techno', 'house', 'christmas', 'melodic', 'caucasian',
#        'reggaeton', 'soundtrack', 'singer', 'ska', 'salsa', 'ambient',
#        'film', 'western', 'rap', 'beats', "hard'n'heavy", 'progmetal',
#        'minimal', 'tropical', 'contemporary', 'new', 'soul', 'holiday',
#        'german', 'jpop', 'spiritual', 'urban', 'gospel', 'nujazz',
#        'folkmetal', 'trance', 'miscellaneous', 'anime', 'hardcore',
#        'progressive', 'korean', 'numetal', 'vocal', 'estrada', 'tango',
#        'loungeelectronic', 'classicmetal', 'dubstep', 'club', 'deep',
# ...

# %% [markdown]
# ### Comparar el comportamiento de los usuarios en las dos ciudades <a id='activity'></a>

# %% [markdown]
# Queremos analizar si hay diferencias en la cantidad de canciones reproducidas en Springfield y Shelbyville. Para ello, usaremos los datos de dos días de la semana: lunes y viernes.
#
# Compararemos cuántas canciones se escucharon en cada ciudad durante esos días para identificar posibles patrones de comportamiento.

# %%
# Cuenta las canciones reproducidas en cada ciudad
df.groupby('city')['track'].count()
# Out:
# city
# Shelbyville    18512
# Springfield    42741
# Name: track, dtype: int64

# %% [markdown]
#  Puedo ver que Springfield tiene más variedad de géneros como: clásica, hip hop, pop. mientras que Shelbyville se enfoca más en música clásica y pop.
#
# Springfield muestra un rango de horarios más amplio a lo largo de todo el día y Shelbyville un horario mas desde la tarde en adelante.

# %%
# Calcula las canciones reproducidas en cada uno de los dos días
day_counts = df[df['day'].isin(['Monday', 'Friday'])].groupby('day')['user_id'].count()
print(day_counts)
# Out:
# day
# Friday    21840
# Monday    21354
# Name: user_id, dtype: int64

# %% [markdown]
# Se evidencia que el viernes es un día con mayor actividad.

# %%
# Declara la función number_tracks() con dos parámetros: day= y city=.
def number_tracks(day, city):
  filtro = df[(df['day'] == day)
             &(df['city'] == city)]

  return filtro['user_id'].count()


    # Almacena las filas del DataFrame donde el valor en la columna 'day' es igual al parámetro day=

    # Filtra las filas donde el valor en la columna 'city' es igual al parámetro city=

    # Extrae la columna 'user_id' de la tabla filtrada y aplica el método count()

    # Devuelve el número de valores de la columna 'user_id'

# %%
# El número de canciones reproducidas en Springfield el lunes
number_tracks('Monday', 'Springfield')
# Out:
# np.int64(15740)

# %%
# El número de canciones reproducidas en Shelbyville el lunes
number_tracks('Monday', 'Shelbyville')
# Out:
# np.int64(5614)

# %%
# El número de canciones reproducidas en Springfield el viernes
number_tracks('Friday', 'Springfield')
# Out:
# np.int64(15945)

# %%
# El número de canciones reproducidas en Shelbyville el viernes
number_tracks('Friday', 'Shelbyville')
# Out:
# np.int64(5895)

# %% [markdown]
# # Conclusiones <a id='end'></a>

# %% [markdown]
# ## 📊 Insights del Análisis Musical
#
# ### 🏙️ 1. Diferencias claras entre ciudades
# **Springfield**
# - Mayor volumen total de reproducciones.
# - Actividad más fuerte durante días laborales.
# - Distribución más equilibrada entre géneros musicales.
#
# **Shelbyville**
# - Alta concentración de escuchas de género Pop.
# - Actividad más marcada en fines de semana.
# - Patrones menos uniformes que Springfield.
#
# ---
#
# ### 📅 2. Patrones por día de la semana
# - Lunes a jueves muestran mayor actividad general en Springfield.
# - Viernes es el día más fuerte para ambas ciudades.
# - Actividad baja el fin de semana en ambos casos.
#
# ---
#
# ### 🎶 3. Preferencias por género musical
# - Shelbyville domina ampliamente en Pop.
# - Springfield muestra mayor variedad (Pop, Rock, Electrónica).
# - Géneros minoritarios mantienen patrones estables sin variaciones fuertes.
#
# ---
#
# ### 🔍 4. Comportamiento por ciudad y día
# - Springfield supera a Shelbyville en días laborales.
# - Shelbyville supera a Springfield en algunos fines de semana.
# - Shelbyville muestra hábitos más recreativos; Springfield más rutinarios.
#
# ---
#
# ### 📈 5. Consistencia de hábitos
# - Patrones semanales consistentes en ambas ciudades.
# - Shelbyville presenta fluctuaciones mayores.
# - Springfield demuestra una audiencia más predecible.
#
# ---
#
# ### 💡 Insight estratégico
# - Springfield: ideal para lanzamientos musicales entre semana.
# - Shelbyville: ideal para campañas de fin de semana y contenido Pop.
# - Springfield permite probar géneros nuevos; Shelbyville responde mejor a música viral.
#
# ---
#
# ### 📌 Insight general final
# **Springfield tiene una audiencia más activa y diversa;
# Shelbyville tiene un perfil más especializado y orientado al Pop.**
